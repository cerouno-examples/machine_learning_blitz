# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
file_prepend = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed."

# %%
cities = ["cleveland.data", "hungarian.data", "switzerland.data", "va.data"]

# %%
output = pd.DataFrame()
for city in cities:
    loaded = pd.read_csv(file_prepend + city, names= ["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","num"]).reset_index()
    output = pd.concat([output, loaded])

# %%
output.head(5)
# Out:
#    index   age  sex   cp trestbps chol fbs restecg thalach exang oldpeak  \
# 0      0  63.0  1.0  1.0      145  233   1       2     150     0     2.3
# 1      1  67.0  1.0  4.0      160  286   0       2     108     1     1.5
# 2      2  67.0  1.0  4.0      120  229   0       2     129     1     2.6
# 3      3  37.0  1.0  3.0      130  250   0       0     187     0     3.5
# 4      4  41.0  0.0  2.0      130  204   0       2     172     0     1.4
#
#   slope   ca thal  num
# 0     3  0.0  6.0    0
# 1     2  3.0  3.0    2
# 2     2  2.0  7.0    1
# 3     3  0.0  3.0    0
# 4     1  0.0  3.0    0

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
output = output.replace("?", np.nan)

# %%
output = output.dropna(axis=0)

# %%
numitems = len(output)
percenttrain = 0.85
numtrain = int(numitems*percenttrain)
numtest = numitems - numtrain
print ('Training set', numtrain, 'items')
print ('Test set', numtest, 'items')
outputTrain = output[0:numtrain]
outputTest = output[numtrain:]
# Out:
# Training set 254 items
# Test set 45 items

# %%
features = list(output.keys())[:-1]

# %%
outputTrain
# Out:
#      index   age  sex   cp trestbps chol fbs restecg thalach exang oldpeak  \
# 0        0  63.0  1.0  1.0      145  233   1       2     150     0     2.3
# 1        1  67.0  1.0  4.0      160  286   0       2     108     1     1.5
# 2        2  67.0  1.0  4.0      120  229   0       2     129     1     2.6
# 3        3  37.0  1.0  3.0      130  250   0       0     187     0     3.5
# 4        4  41.0  0.0  2.0      130  204   0       2     172     0     1.4
# 5        5  56.0  1.0  2.0      120  236   0       0     178     0     0.8
# 6        6  62.0  0.0  4.0      140  268   0       2     160     0     3.6
# 7        7  57.0  0.0  4.0      120  354   0       0     163     1     0.6
# 8        8  63.0  1.0  4.0      130  254   0       2     147     0     1.4
# 9        9  53.0  1.0  4.0      140  203   1       2     155     1     3.1
# 10      10  57.0  1.0  4.0      140  192   0       0     148     0     0.4
# 11      11  56.0  0.0  2.0      140  294   0       2     153     0     1.3
# 12      12  56.0  1.0  3.0      130  256   1       2     142     1     0.6
# 13      13  44.0  1.0  2.0      120  263   0       0     173     0       0
# 14      14  52.0  1.0  3.0      172  199   1       0     162     0     0.5
# 15      15  57.0  1.0  3.0      150  168   0       0     174     0     1.6
# 16      16  48.0  1.0  2.0      110  229   0       0     168     0       1
# 17      17  54.0  1.0  4.0      140  239   0       0     160     0     1.2
# 18      18  48.0  0.0  3.0      130  275   0       0     139     0     0.2
# 19      19  49.0  1.0  2.0      130  266   0       0     171     0     0.6
# 20      20  64.0  1.0  1.0      110  211   0       2     144     1     1.8
# 21      21  58.0  0.0  1.0      150  283   1       2     162     0       1
# 22      22  58.0  1.0  2.0      120  284   0       2     160     0     1.8
# 23      23  58.0  1.0  3.0      132  224   0       2     173     0     3.2
# 24      24  60.0  1.0  4.0      130  206   0       2     132     1     2.4
# 25      25  50.0  0.0  3.0      120  219   0       0     158     0     1.6
# 26      26  58.0  0.0  3.0      120  340   0       0     172     0       0
# 27      27  66.0  0.0  1.0      150  226   0       0     114     0     2.6
# 28      28  43.0  1.0  4.0      150  247   0       0     171     0     1.5
# 29      29  40.0  1.0  4.0      110  167   0       2     114     1       2
# ..     ...   ...  ...  ...      ...  ...  ..     ...     ...   ...     ...
# 227    227  67.0  0.0  3.0      152  277   0       0     172     0       0
# 228    228  54.0  1.0  4.0      110  206   0       2     108     1       0
# 229    229  66.0  1.0  4.0      112  212   0       2     132     1     0.1
# 230    230  52.0  0.0  3.0      136  196   0       2     169     0     0.1
# 231    231  55.0  0.0  4.0      180  327   0       1     117     1     3.4
# 232    232  49.0  1.0  3.0      118  149   0       2     126     0     0.8
# 233    233  74.0  0.0  2.0      120  269   0       2     121     1     0.2
# 234    234  54.0  0.0  3.0      160  201   0       0     163     0       0
# 235    235  54.0  1.0  4.0      122  286   0       2     116     1     3.2
# 236    236  56.0  1.0  4.0      130  283   1       2     103     1     1.6
# 237    237  46.0  1.0  4.0      120  249   0       2     144     0     0.8
# 238    238  49.0  0.0  2.0      134  271   0       0     162     0       0
# 239    239  42.0  1.0  2.0      120  295   0       0     162     0       0
# 240    240  41.0  1.0  2.0      110  235   0       0     153     0       0
# 241    241  41.0  0.0  2.0      126  306   0       0     163     0       0
# 242    242  49.0  0.0  4.0      130  269   0       0     163     0       0
# 243    243  61.0  1.0  1.0      134  234   0       0     145     0     2.6
# 244    244  60.0  0.0  3.0      120  178   1       0      96     0       0
# 245    245  67.0  1.0  4.0      120  237   0       0      71     0       1
# 246    246  58.0  1.0  4.0      100  234   0       0     156     0     0.1
# 247    247  47.0  1.0  4.0      110  275   0       2     118     1       1
# 248    248  52.0  1.0  4.0      125  212   0       0     168     0       1
# 249    249  62.0  1.0  2.0      128  208   1       2     140     0       0
# 250    250  57.0  1.0  4.0      110  201   0       0     126     1     1.5
# 251    251  58.0  1.0  4.0      146  218   0       0     105     0       2
# 252    252  64.0  1.0  4.0      128  263   0       0     105     1     0.2
# 253    253  51.0  0.0  3.0      120  295   0       2     157     0     0.6
# 254    254  43.0  1.0  4.0      115  303   0       0     181     0     1.2
# 255    255  42.0  0.0  3.0      120  209   0       0     173     0       0
# 256    256  67.0  0.0  4.0      106  223   0       0     142     0     0.3
#
#     slope   ca thal  num
# 0       3  0.0  6.0    0
# 1       2  3.0  3.0    2
# 2       2  2.0  7.0    1
# 3       3  0.0  3.0    0
# 4       1  0.0  3.0    0
# 5       1  0.0  3.0    0
# 6       3  2.0  3.0    3
# 7       1  0.0  3.0    0
# 8       2  1.0  7.0    2
# 9       3  0.0  7.0    1
# 10      2  0.0  6.0    0
# 11      2  0.0  3.0    0
# 12      2  1.0  6.0    2
# 13      1  0.0  7.0    0
# 14      1  0.0  7.0    0
# 15      1  0.0  3.0    0
# 16      3  0.0  7.0    1
# 17      1  0.0  3.0    0
# 18      1  0.0  3.0    0
# 19      1  0.0  3.0    0
# 20      2  0.0  3.0    0
# 21      1  0.0  3.0    0
# 22      2  0.0  3.0    1
# 23      1  2.0  7.0    3
# 24      2  2.0  7.0    4
# 25      2  0.0  3.0    0
# 26      1  0.0  3.0    0
# 27      3  0.0  3.0    0
# 28      1  0.0  3.0    0
# 29      2  0.0  7.0    3
# ..    ...  ...  ...  ...
# 227     1  1.0  3.0    0
# 228     2  1.0  3.0    3
# 229     1  1.0  3.0    2
# 230     2  0.0  3.0    0
# 231     2  0.0  3.0    2
# 232     1  3.0  3.0    1
# 233     1  1.0  3.0    0
# 234     1  1.0  3.0    0
# 235     2  2.0  3.0    3
# 236     3  0.0  7.0    2
# 237     1  0.0  7.0    1
# 238     2  0.0  3.0    0
# 239     1  0.0  3.0    0
# 240     1  0.0  3.0    0
# 241     1  0.0  3.0    0
# 242     1  0.0  3.0    0
# 243     2  2.0  3.0    2
# 244     1  0.0  3.0    0
# 245     2  0.0  3.0    2
# 246     1  1.0  7.0    2
# 247     2  1.0  3.0    1
# 248     1  2.0  7.0    3
# 249     1  0.0  3.0    0
# 250     2  0.0  6.0    0
# 251     2  1.0  7.0    1
# 252     2  1.0  7.0    0
# 253     1  0.0  3.0    0
# 254     2  0.0  3.0    0
# 255     2  0.0  3.0    0
# 256     1  2.0  3.0    0
#
# [254 rows x 15 columns]

# %%
neighbors = 8
classifier = KNeighborsClassifier(neighbors)
classifier.fit(outputTrain[features], outputTrain['num'])
predictions = classifier.predict(outputTest[features])


# Calculate accuracy
prediccionesCorrectas=[predictions==outputTest['num'].values]
accuracy= np.sum(prediccionesCorrectas) / len(predictions)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.4

# %%
trees = 100
rf = RandomForestClassifier(n_estimators=trees, class_weight="balanced")
rf.fit(outputTrain[features],outputTrain['num'])
predictions = rf.predict(outputTest[features])

# Calculate accuracy
prediccionesCorrectas=[predictions==outputTest['num'].values]
accuracy= np.sum(prediccionesCorrectas) / len(predictions)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.4666666666666667

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(outputTest['num'],predictions)
# Out:
# array([[18,  0,  0,  0,  0],
#        [ 9,  1,  0,  2,  0],
#        [ 2,  1,  2,  4,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 0,  0,  1,  1,  0]])

# %%
relevant_features = [features[i] for i, value in enumerate(rf.feature_importances_ ) if rf.feature_importances_[i]>0.05]

# %%
trees = 100
rf = RandomForestClassifier(n_estimators=trees)
rf.fit(outputTrain[relevant_features],outputTrain['num'])
predictions = rf.predict(outputTest[relevant_features])

# Calculate accuracy
prediccionesCorrectas=[predictions==outputTest['num'].values]
accuracy= np.sum(prediccionesCorrectas) / len(predictions)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.32608695652173914
