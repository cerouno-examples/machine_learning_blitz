# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
file_prepend = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed."

# %%
cities = ["cleveland.data", "hungarian.data", "switzerland.data", "va.data"]

# %%
output = pd.DataFrame()
for city in cities:
    loaded = pd.read_csv(file_prepend + city, names= ["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","num"]).reset_index()
    output = pd.concat([output, loaded])

# %%
output.head(5)
# Out:
#    index   age  sex   cp trestbps chol fbs restecg thalach exang oldpeak  \
# 0      0  63.0  1.0  1.0      145  233   1       2     150     0     2.3
# 1      1  67.0  1.0  4.0      160  286   0       2     108     1     1.5
# 2      2  67.0  1.0  4.0      120  229   0       2     129     1     2.6
# 3      3  37.0  1.0  3.0      130  250   0       0     187     0     3.5
# 4      4  41.0  0.0  2.0      130  204   0       2     172     0     1.4
#
#   slope   ca thal  num
# 0     3  0.0  6.0    0
# 1     2  3.0  3.0    2
# 2     2  2.0  7.0    1
# 3     3  0.0  3.0    0
# 4     1  0.0  3.0    0

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
output.median()
# Out:
# index    114.5
# age       54.0
# sex        1.0
# cp         4.0
# num        1.0
# dtype: float64

# %%
for key in list(output.keys()):
    median = output.replace("?", np.nan).dropna()[key].median()
    output[key]  =output[key].replace("?", median)

# %%
numitems = len(output)
percenttrain = 0.85
numtrain = int(numitems*percenttrain)
numtest = numitems - numtrain
print ('Training set', numtrain, 'items')
print ('Test set', numtest, 'items')
outputTrain = output[0:numtrain]
outputTest = output[numtrain:]
# Out:
# Training set 782 items
# Test set 138 items

# %%
features = list(output.keys())[:-1]

# %%
outputTrain
# Out:
#     index   age  sex   cp trestbps chol fbs restecg thalach exang oldpeak  \
# 0       0  63.0  1.0  1.0      145  233   1       2     150     0     2.3
# 1       1  67.0  1.0  4.0      160  286   0       2     108     1     1.5
# 2       2  67.0  1.0  4.0      120  229   0       2     129     1     2.6
# 3       3  37.0  1.0  3.0      130  250   0       0     187     0     3.5
# 4       4  41.0  0.0  2.0      130  204   0       2     172     0     1.4
# 5       5  56.0  1.0  2.0      120  236   0       0     178     0     0.8
# 6       6  62.0  0.0  4.0      140  268   0       2     160     0     3.6
# 7       7  57.0  0.0  4.0      120  354   0       0     163     1     0.6
# 8       8  63.0  1.0  4.0      130  254   0       2     147     0     1.4
# 9       9  53.0  1.0  4.0      140  203   1       2     155     1     3.1
# 10     10  57.0  1.0  4.0      140  192   0       0     148     0     0.4
# 11     11  56.0  0.0  2.0      140  294   0       2     153     0     1.3
# 12     12  56.0  1.0  3.0      130  256   1       2     142     1     0.6
# 13     13  44.0  1.0  2.0      120  263   0       0     173     0       0
# 14     14  52.0  1.0  3.0      172  199   1       0     162     0     0.5
# 15     15  57.0  1.0  3.0      150  168   0       0     174     0     1.6
# 16     16  48.0  1.0  2.0      110  229   0       0     168     0       1
# 17     17  54.0  1.0  4.0      140  239   0       0     160     0     1.2
# 18     18  48.0  0.0  3.0      130  275   0       0     139     0     0.2
# 19     19  49.0  1.0  2.0      130  266   0       0     171     0     0.6
# 4      1  0.0  3.0    0
# 5      1  0.0  3.0    0
# 6      3  2.0  3.0    3
# 7      1  0.0  3.0    0
# 8      2  1.0  7.0    2
# 9      3  0.0  7.0    1
# 10     2  0.0  6.0    0
# 11     2  0.0  3.0    0
# 12     2  1.0  6.0    2
# 13     1  0.0  7.0    0
# 14     1  0.0  7.0    0
# 15     1  0.0  3.0    0
# 16     3  0.0  7.0    1
# 17     1  0.0  3.0    0
# 18     1  0.0  3.0    0
# 19     1  0.0  3.0    0
# 20     2  0.0  3.0    0
# 21     1  0.0  3.0    0
# 22     2  0.0  3.0    1
# 23     1  2.0  7.0    3
# 24     2  2.0  7.0    4
# 25     2  0.0  3.0    0
# 26     1  0.0  3.0    0
# 27     3  0.0  3.0    0
# 28     1  0.0  3.0    0
# 29     2  0.0  7.0    3
# ..   ...  ...  ...  ...
# 32     2    0    0    3
# 33     2    0    0    3
# 34     3    0    0    2
# 35     2    0    0    3
# 36     0    0    0    2
# 37     1    0    7    0
# 38     0    0    0    1
# 39     0    0    0    0
# 40     2    0    0    3
# 41     0    0    7    1
# 42     2    0    7    3
# 43     0    0    0    0
# 44     0    0    0    4
# 45     0    0    7    2
# 46     3    0    0    1
# 47     0    0    0    0
# 48     3    0    0    2
# 49     0    0    0    0
# 50     2    0    7    1
# 51     0    0    0    0
# 52     1    0    7    2
# 53     2    0    0    0
# 54     0    0    0    1
# 55     2    0    0    2
# 56     2    0    0    2
# 57     0    0    0    3
# 58     0    0    0    0
# 59     0    0    7    1
# 60     0    0    0    0
# 61     3    0    0    2
#
# [782 rows x 15 columns]

# %%
out
# Out:
# -------------------------------------------------------
# NameError             Traceback (most recent call last)
# <ipython-input-76-fb7792b6596f> in <module>()
# ----> 1 out
#
# NameError: name 'out' is not defined

# %%
neighbors = 8
classifier = KNeighborsClassifier(neighbors)
classifier.fit(outputTrain[features], outputTrain['num'])
predictions = classifier.predict(outputTest[features])


# Calculate accuracy
prediccionesCorrectas=[predictions==outputTest['num'].values]
accuracy= np.sum(prediccionesCorrectas) / len(predictions)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.2971014492753623

# %%
trees = 100
rf = RandomForestClassifier(n_estimators=trees, class_weight="balanced")
rf.fit(outputTrain[features],outputTrain['num'])
predictions = rf.predict(outputTest[features])

# Calculate accuracy
prediccionesCorrectas=[predictions==outputTest['num'].values]
accuracy= np.sum(prediccionesCorrectas) / len(predictions)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.2971014492753623

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(outputTest['num'],predictions)
# Out:
# array([[26,  7,  0,  0,  0],
#        [21, 12,  1,  6,  0],
#        [11, 12,  1,  3,  0],
#        [15, 11,  2,  2,  0],
#        [ 3,  3,  1,  1,  0]])

# %%
relevant_features = [features[i] for i, value in enumerate(rf.feature_importances_ ) if rf.feature_importances_[i]>0.05]

# %%
trees = 100
rf = RandomForestClassifier(n_estimators=trees)
rf.fit(outputTrain[relevant_features],outputTrain['num'])
predictions = rf.predict(outputTest[relevant_features])

# Calculate accuracy
prediccionesCorrectas=[predictions==outputTest['num'].values]
accuracy= np.sum(prediccionesCorrectas) / len(predictions)
print('Accuracy: ', accuracy)
# Out:
# Accuracy:  0.32608695652173914

# %%
rf.feature_importances_
# Out:
# array([0.17413542, 0.10529162, 0.10578753, 0.09238503, 0.09831405,
#        0.12101883, 0.09543551, 0.07508494, 0.04220564, 0.09034143])
